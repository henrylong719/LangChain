# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

# %%
from langchain.tools import tool

@tool
def sql_query(query: str) -> str:

    """Obtain information from the database using SQL queries"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

sql_query.invoke("SELECT * FROM Artist LIMIT 10")
# Out:
# "[(1, 'AC/DC'), (2, 'Accept'), (3, 'Aerosmith'), (4, 'Alanis Morissette'), (5, 'Alice In Chains'), (6, 'Antônio Carlos Jobim'), (7, 'Apocalyptica'), (8, 'Audioslave'), (9, 'BackBeat'), (10, 'Billy Cobham')]"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[sql_query]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?", additional_kwargs={}, response_metadata={}, id='9b99b80e-d73d-4296-a576-003b85202e74'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 744, 'prompt_tokens': 142, 'total_tokens': 886, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7ZCrIXVV9Ge05ewm8MX4SHX1Z4OO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c45b4-c722-7861-8046-a203206d04bc-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;"}, 'id': 'call_fGmqUoP8QV1vfmE7Nqd0jnUe', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 142, 'output_tokens': 744, 'total_tokens': 886, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#  ToolMessage(content="Error: (sqlite3.OperationalError) no such table: artists\n[SQL: SELECT name FROM artists WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)", name='sql_query', id='686bdfa5-eaee-4847-bad1-54f59a484c7a', tool_call_id='call_fGmqUoP8QV1vfmE7Nqd0jnUe'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 356, 'prompt_tokens': 245, 'total_tokens': 601, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7ZCxEzUO5VIsvD5qGYpV57HkSoaO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c45b4-df92-7e61-ac37-9a8841c3d0df-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;"}, 'id': 'call_jLKp2szDvUejRQBCZq2u8huA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 245, 'output_tokens': 356, 'total_tokens': 601, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#  ToolMessage(content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]", name='sql_query', id='2b056842-fae9-4839-a896-9f45fdaa3c3d', tool_call_id='call_jLKp2szDvUejRQBCZq2u8huA'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 334, 'total_tokens': 368, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7ZD0WKchKgqHl7yNXCRf0W2I9wRR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c45b4-eaad-74c0-ace8-c5059c07227e-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM Artist WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;"}, 'id': 'call_I58vzIysdrWsuOtIqh6niUDr', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 334, 'output_tokens': 34, 'total_tokens': 368, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="Error: (sqlite3.OperationalError) no such column: popularity\n[SQL: SELECT name FROM Artist WHERE name LIKE 'S%' ORDER BY popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)", name='sql_query', id='63fb7f51-bfb0-442d-b890-192d78b81734', tool_call_id='call_I58vzIysdrWsuOtIqh6niUDr'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 437, 'total_tokens': 460, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7ZD2edrKPgFfX8K1aLwvR4LYl9x6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c45b4-ee8d-7fb0-a801-e588767bd17a-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'PRAGMA table_info(Artist);'}, 'id': 'call_2MLix0ibP7AQwK5nNySEMdBj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 437, 'output_tokens': 23, 'total_tokens': 460, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="[(0, 'ArtistId', 'INTEGER', 1, None, 1), (1, 'Name', 'NVARCHAR(120)', 0, None, 0)]", name='sql_query', id='49beb6a0-db4d-4022-bc2f-c7e6b9aeafa9', tool_call_id='call_2MLix0ibP7AQwK5nNySEMdBj'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 920, 'prompt_tokens': 509, 'total_tokens': 1429, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7ZD3TlzX5ckoJC6hCYHvAYKKqxaD', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c45b4-f486-70f3-bf3a-f5df2bbf6df0-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT a.Name, COUNT(*) AS TrackCount\nFROM Artist a\nJOIN Album al ON al.ArtistId = a.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nWHERE a.Name LIKE 'S%'\nGROUP BY a.Name\nORDER BY TrackCount DESC\nLIMIT 1;"}, 'id': 'call_VQgO2oKHsNB0UipfCDqsIaLD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 509, 'output_tokens': 920, 'total_tokens': 1429, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#  ToolMessage(content="[('Smashing Pumpkins', 34)]", name='sql_query', id='44636f17-b103-4c63-a5e2-c61b7f371b9e', tool_call_id='call_VQgO2oKHsNB0UipfCDqsIaLD'),
#  AIMessage(content="The most popular artist whose name starts with 'S' is: Smashing Pumpkins.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 612, 'total_tokens': 633, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7ZDBEzVRuSDdRJwU4PiHEUBd0f6a', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c45b5-129c-75e3-b218-44734be00596-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 612, 'output_tokens': 21, 'total_tokens': 633, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# Safely get the SQL query from the first message that made a tool call
messages = response["messages"]
for msg in reversed(messages):
    tool_calls = getattr(msg, "tool_calls", None) or []
    if tool_calls and tool_calls[0].get("args", {}).get("query"):
        print(tool_calls[0]["args"]["query"])
        break
else:
    print("No SQL tool call in this response (agent may have asked a follow-up instead).")
# Out:
# SELECT a.Name, COUNT(*) AS TrackCount
# FROM Artist a
# JOIN Album al ON al.ArtistId = a.ArtistId
# JOIN Track t ON t.AlbumId = al.AlbumId
# WHERE a.Name LIKE 'S%'
# GROUP BY a.Name
# ORDER BY TrackCount DESC
# LIMIT 1;
