# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='e9f30318-3432-4dc5-947b-30998ae17bfb'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 446, 'prompt_tokens': 1229, 'total_tokens': 1675, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7VIjqSAfDLGbcOuaXqAH8Tkis8QK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c44cf-b132-7073-a447-c6fc89a66199-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'passengers': {'adults': 1}, 'cabinClass': 'M', 'curr': 'EUR', 'locale': 'en'}, 'id': 'call_Nk6Hs325r1cniBdfcwBORHr1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 446, 'total_tokens': 1675, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T06:55:00.000Z",\n      "local": "2026-04-01T15:55:00.000"\n    },\n    "totalDurationInSeconds": 83100,\n    "durationInSeconds": 83100,\n    "price": 546,\n    "deepLink": "https://on.kiwi.com/Vi6EbI",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T22:50:00.000Z",\n          "local": "2026-04-01T06:50:00.000"\n        }\n      },\n      {\n        "at": "MYJ",\n        "city": "Matsuyama",\n        "cityCode": "MYJ",\n        "arrival": {\n          "utc": "2026-04-01T01:15:00.000Z",\n          "local": "2026-04-01T10:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T05:25:00.000Z",\n          "local": "2026-04-01T14:25:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T07:50:00.000Z",\n      "local": "2026-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T09:10:00.000Z",\n      "local": "2026-04-01T18:10:00.000"\n    },\n    "totalDurationInSeconds": 91200,\n    "durationInSeconds": 91200,\n    "price": 571,\n    "deepLink": "https://on.kiwi.com/9FBAUU",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:40:00.000Z",\n          "local": "2026-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2026-03-31T22:50:00.000Z",\n          "local": "2026-04-01T06:50:00.000"\n        }\n      },\n      {\n        "at": "MYJ",\n        "city": "Matsuyama",\n        "cityCode": "MYJ",\n        "arrival": {\n          "utc": "2026-04-01T01:15:00.000Z",\n          "local": "2026-04-01T10:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T07:35:00.000Z",\n          "local": "2026-04-01T16:35:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T08:05:00.000Z",\n      "local": "2026-03-31T01:05:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T10:00:00.000Z",\n      "local": "2026-04-01T19:00:00.000"\n    },\n    "totalDurationInSeconds": 93300,\n    "durationInSeconds": 93300,\n    "price": 523,\n    "deepLink": "https://on.kiwi.com/mrL8Ap",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-03-31T21:35:00.000Z",\n          "local": "2026-04-01T05:35:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T06:35:00.000Z",\n          "local": "2026-04-01T14:35:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T08:05:00.000Z",\n      "local": "2026-03-31T01:05:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-01T06:20:00.000Z",\n      "local": "2026-04-01T15:20:00.000"\n    },\n    "totalDurationInSeconds": 80100,\n    "durationInSeconds": 80100,\n    "price": 579,\n    "deepLink": "https://on.kiwi.com/p72NsK",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n      ...
#               AIMessage(content='Here are the direct flight options from San Francisco (SFO) to Tokyo (NRT) on March 31, 2026.\n\nCheapest direct flight\n- Flight: SFO → NRT\n- Schedule: 31/03/2026 12:20 → 01/04/2026 15:25 (11h 5m)\n- Cabin: Economy\n- Return: n/a\n- Price: EUR 1060\n- Book: https://on.kiwi.com/pTBGRf\n\nShortest direct flight\n- Flight: SFO → NRT\n- Schedule: 31/03/2026 12:20 → 01/04/2026 15:25 (11h 5m)\n- Cabin: Economy\n- Return: n/a\n- Price: EUR 1060\n- Book: https://on.kiwi.com/pTBGRf\n\n- Flight: SFO → NRT\n- Schedule: 31/03/2026 12:20 → 01/04/2026 15:25 (11h 5m)\n- Cabin: Economy\n- Return: n/a\n- Price: EUR 1097\n- Book: https://on.kiwi.com/1FSyMg\n\nRecommendation\n- Best price: EUR 1060 for a direct SFO→NRT on 31/03/2026\n- Best duration: both direct options are the same 11h 5m\n- If you want the cheaper option, pick the EUR 1060 flight (book link above). If you’d prefer a lightly different fare, the EUR 1097 direct option is also available.\n\nHave a wonderful trip! Fun fact: Tokyo blends ultramodern architecture with centuries-old traditions—from neon-lit Shibuya crossings to tranquil gardens and ancient temples.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5834, 'prompt_tokens': 6724, 'total_tokens': 12558, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 5440, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7VIqmmBcgYtdNW7aipx5f33Lch3K', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c44cf-d060-76d1-862f-a601eabbd033-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6724, 'output_tokens': 5834, 'total_tokens': 12558, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 5440}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are the direct flight options from San Francisco (SFO) to Tokyo (NRT) on March 31, 2026.
#
# Cheapest direct flight
# - Flight: SFO → NRT
# - Schedule: 31/03/2026 12:20 → 01/04/2026 15:25 (11h 5m)
# - Cabin: Economy
# - Return: n/a
# - Price: EUR 1060
# - Book: https://on.kiwi.com/pTBGRf
#
# Shortest direct flight
# - Flight: SFO → NRT
# - Schedule: 31/03/2026 12:20 → 01/04/2026 15:25 (11h 5m)
# - Cabin: Economy
# - Return: n/a
# - Price: EUR 1060
# - Book: https://on.kiwi.com/pTBGRf
#
# - Flight: SFO → NRT
# - Schedule: 31/03/2026 12:20 → 01/04/2026 15:25 (11h 5m)
# - Cabin: Economy
# - Return: n/a
# - Price: EUR 1097
# - Book: https://on.kiwi.com/1FSyMg
#
# Recommendation
# - Best price: EUR 1060 for a direct SFO→NRT on 31/03/2026
# - Best duration: both direct options are the same 11h 5m
# - If you want the cheaper option, pick the EUR 1060 flight (book link above). If you’d prefer a lightly different fare, the EUR 1097 direct option is also available.
#
# Have a wonderful trip! Fun fact: Tokyo blends ultramodern architecture with centuries-old traditions—from neon-lit Shibuya crossings to tranquil gardens and ancient temples.
