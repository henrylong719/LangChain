# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Real-world answer: There is no capital of the Moon—it's not a country and has no government.
#
# Fictional capital for a sci‑fi setting:
# - Name: Lunaris Prime
# - Role: Capital of the Lunar Commonwealth (a political entity that governs the Moon)
# - Location: perched on the rim of Shackleton Crater at the lunar south pole, where perpetual sunlight peaks meet shadowed ice—ideal for solar power and water ice harvesting
# - Government hub: the Grand Orbital—home to the Lunar Assembly, the High Chancellor’s residence, and the Crown of Glass (a sky-lit beacon that doubles as the city’s solar collector)
# - Notable landmarks:
#   - The Earthview Spire: a crystalline tower offering panoramic views of Earth
#   - The Helium-3 Promenade: a ring-lined plaza built around a repurposed mining shaft
#   - The Lumen Gate: a shimmering entrance to the city’s domed districts
# - Economy and culture: powered by helium-3 mining, water ice, and orbital trade; a culture of engineers, scientists, miners, and artists who craft elegant, polyglot communities inside shielded domes
# - City feel: bright, glassy architecture with radiative gardens; a quiet, precise pace, punctuated by shuttle bells and the hum of mag-lev corridors
#
# If you’d like a different vibe (more militarized, more utopian, more frontier-style), tell me your preferred setting and I’ll tailor the capital name and details.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png.jpg', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png.jpg', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon_city.jpg', 'type': 'image/jpeg', 'size': 734360, 'content': <memory at 0x119284640>, 'last_modified': datetime.datetime(2026, 2, 9, 22, 46, 39, 623000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s the capital that the image hints at. I call it Lunaris Prime, the gleaming heart of the Moon-Tide Union on the world of Asteria. It’s a city built to live with the Moon rather than against it, a place where night and day blend into a single, electric lifetime.
#
# What Lunaris Prime feels like
# - The Moon as a constant companion: Asteria’s moon is enormous in the sky, its light soft and crystalline. The city is designed to glow with that light—streets, parks, and façades bathed in a cool, blue luminescence. At dusk, the city doesn’t darken so much as shift into a deeper, more reflective mood.
# - Architecture that breathes: Skyscrapers are tall but not purely vertical; they twist, arc, and hinge at terraces. Buildings are wrapped in glass and lattice skin that harvests lunar energy and rainwater. Bridges of light connect districts high above street level, letting pedestrians glide between neighborhoods without touching ground.
# - An arcology-centered metropolis: Much of Lunaris Prime is a series of superdense megastructures—living, working, and farming within and atop colossal habitats. Farms hang like vertical gardens from balconies; solar and lunar collectors shimmer on every roof; wind farms coil around the base of towers like steel vines.
# - A governance built for a new age: The Crescent Council governs with a blend of technocratic expertise and citizen assemblies. Decisions are framed as “adjustments to the Moon’s mood” and implemented through autonomous districts that tailor policy to their microclimate and economy.
#
# Key districts and landmarks
# - Observatorium Quarter: Home to the Great Moon Observatory and the Lunar Research Institute. A place of experiments in gravity, tides, and xenolinguistics; ambassadors and researchers mingle with curious citizens in glass walkways above the rain-slick streets.
# - Crescent Quarter (Seat of Government): The seat of the Crescent Council, where parliament towers reach toward the Moon. Courts, ministries, and public forums sit under a giant, sculpted crescent that glows faintly at night.
# - Nocturne Arts District: A vibrant neighborhood of theaters, holographic galleries, and music halls. Street performances use anti-gravity platforms and resonant wood instruments that hum with lunar energy.
# - Harbor of Echoes: The city’s port and spaceport, where lunar-fueled freighters dock and the Echo Market thrives with cybernetic crafters, spice merchants, and bioluminescent vendors selling holographic wares.
# - Helio Cliffs: Industrial and biotech hub. Dome-roofed labs grow bacteria cultures for medicine and materials, while hydroponic farms on the cliff faces feed the city.
# - Subterranean Gardens: A vast, climate-controlled network beneath the city—farms, fresh-water reservoirs, and caves turned into collaborative studios for artists and tinkers.
#
# How people live here
# - Daily life: The rhythm of the city follows a lunar timetable. Public spaces activate in sync with the Moon’s phase—certain parks glow brighter on a full-mmoon night; transit hubs adjust frequency with the tides.
# - Fashion and culture: People wear light, reflective fabrics that shimmer with the Moon’s glow. Tattoos and skin art form elements of identity—glowing glyphs that react to mood and the Moon’s phase.
# - Economy: A mix of lunar-resource processing, biotech, and high-technology services. Lunar energy tokens power most transactions; gravity-stable districts host markets where weightless commerce is the norm.
# - Energy and environment: Lunar and tidal energy are integrated into a single grid. Waste becomes resource through advanced recycling and biomass conversion. The air feels cool but breathable, with a faint mineral scent from the Moon’s dust and distant oceans.
#
# A quick lore snapshot
# - Founding myth: After a failed terraforming mission uncovered an ancient lunar beacon, Lunaris Prime was built around it. The beacon’s code shaped the city’s governance: flexible, responsive, and deeply collaborative.
# - Tides and tempers: The Moon’s gravity subtly sways the city’s infrastructure, prompting engineers to design in adaptable, resilient ways. Construction uses lighter, stronger alloys and megastructures that lean slightly toward the Moon’s pull.
# - Challenges: Nightlife and energy demand strain the grid during new moons when the Moon’s glow intensifies. The Crescent Council counters with adaptive load-sharing, lunar-battery warehouses, and community lighthouses to guide travelers.
#
# If you want, I can tailor Lunaris Prime further:
# - Name and setting adjustments (name of the planet, the ruling faction, or a different moon-spirit lore).
# - A map layout of districts and a short scene in a district you like (Observatorium Quarter at night, or the bustle of Harbor of Echoes).
# - A spark of plot ideas set in this capital (a political crisis during a rare lunar eclipse, a biotech breakthrough that changes how people live, or an expedition launching from the Moonport).

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.53it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# It sounds like the person in the audio is making a playful or imaginative statement about being on the moon. Without more context, it’s likely that they’re either joking or using it as a metaphor. There’s no way to confirm whether they’re actually on the moon just from the audio.
#
# Let me know if you’d like more analysis or transcription.
