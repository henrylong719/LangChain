# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool, ToolRuntime

@tool
def read_email(runtime: ToolRuntime) -> str:
    """Read an email from the given address."""
    # take email from state
    return runtime.state["email"]

@tool
def send_email(body: str) -> str:
    """Send an email to the given address with the given subject and body."""
    # fake email sending
    return f"Email sent"

# %%
from langchain.agents import create_agent, AgentState
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware

class EmailState(AgentState):
    email: str

agent = create_agent(
    model="gpt-5-nano",
    tools=[read_email, send_email],
    state_schema=EmailState,
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "read_email": False,
                "send_email": True,
            },
            description_prefix="Tool execution requires approval",
        ),
    ],
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {
        "messages": [HumanMessage(content="Please read my email and send a response immediately. Send the reply now in the same thread.")],
        "email": "Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John."
    },
    config=config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Hi '
#                                                                           'John,\n'
#                                                                           '\n'
#                                                                           'No '
#                                                                           'problem—thanks '
#                                                                           'for '
#                                                                           'letting '
#                                                                           'me '
#                                                                           'know. '
#                                                                           'I’m '
#                                                                           'available '
#                                                                           'to '
#                                                                           'reschedule. '
#                                                                           'Are '
#                                                                           'you '
#                                                                           'available '
#                                                                           'tomorrow '
#                                                                           'at '
#                                                                           '10:00 '
#                                                                           'AM '
#                                                                           'or '
#                                                                           '2:00 '
#                                                                           'PM? '
#                                                                           'If '
#                                                                           'neither '
#                                                                           'time '
#                                                                           'works, '
#                                                                           'please '
#                                                                           'share '
#                                                                           'a '
#                                                                           'couple '
#                                                                           'of '
#                                                                           'alternatives '
#                                                                           'and '
#                                                                           'I’ll '
#                                                                           'adjust.\n'
#                                                                           '\n'
#                                                                           'Best '
#                                                                           'regards,\n'
#                                                                           'Seán'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'body': "
#                                                                         "'Hi "
#                                                                         'John,\\n\\nNo '
#                                                                         'problem—thanks '
#                                                                         'for '
#                                                                         'letting '
#                                                                         'me '
#                                                                         'know. '
#                                                                         'I’m '
#                                                                         'available '
#                                                                         'to '
#                                                                         'reschedule. '
#                                                                         'Are '
#                                                                         'you '
#                                                                         'available '
#                                                                         'tomorrow '
#                                                                         'at '
#                                                                         '10:00 '
#                                                                         'AM or '
#                                                                         '2:00 '
#                                                                         'PM? '
#                                                                         'If '
#                                                                         'neither '
#                                                                         'time '
#                                                                         'works, '
#                                                                         'please '
#                                                                         'share '
#                                                                         'a '
#                                                                         'couple '
#                                                                         'of '
#                                                                         'alternatives '
#                                                                         'and '
#                                                                         'I’ll '
#                                                                         'adjust.\\n\\nBest '
#                                                                         "regards,\\nSeán'}",
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='fbc92ab0eadbc0e28d18645b945b4092')],
#  'email': "Hi Seán, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Please read my email and send a response immediately. Send the reply now in the same thread.', additional_kwargs={}, response_metadata={}, id='b7284f81-7bad-4e40-9375-6a10c3676487'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 339, 'prompt_tokens': 167, 'total_tokens': 506, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D91Eg9XQamcLpb7Pzl4PXYQHJp9oa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c5a55-6d64-7da1-87f5-02a054eba152-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'call_f0tHN7O8j4qOECidBloP0a29', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 339, 'total_tokens': 506, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#               ToolMessage(content="Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='51e0ae52-53d4-4596-bb46-5039cec21bdb', tool_call_id='call_f0tHN7O8j4qOECidBloP0a29'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 916, 'prompt_tokens': 214, 'total_tokens': 1130, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D91EkA2oExRd5JXuzw1mFU755M0er', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c5a55-7d91-7132-a167-ad202295f4d3-0', tool_calls=[{'name': 'send_email', 'args': {'body': 'Hi John,\n\nNo problem—thanks for letting me know. I’m available to reschedule. Are you available tomorrow at 10:00 AM or 2:00 PM? If neither time works, please share a couple of alternatives and I’ll adjust.\n\nBest regards,\nSeán'}, 'id': 'call_1zxmyUzVIFVrLDZW8L46f4z0', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 916, 'total_tokens': 1130, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}})]}

# %%
print(response['__interrupt__'])
# Out:
# [Interrupt(value={'action_requests': [{'name': 'send_email', 'args': {'body': 'Hi John,\n\nNo problem—thanks for letting me know. I’m available to reschedule. Are you available tomorrow at 10:00 AM or 2:00 PM? If neither time works, please share a couple of alternatives and I’ll adjust.\n\nBest regards,\nSeán'}, 'description': "Tool execution requires approval\n\nTool: send_email\nArgs: {'body': 'Hi John,\\n\\nNo problem—thanks for letting me know. I’m available to reschedule. Are you available tomorrow at 10:00 AM or 2:00 PM? If neither time works, please share a couple of alternatives and I’ll adjust.\\n\\nBest regards,\\nSeán'}"}], 'review_configs': [{'action_name': 'send_email', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='fbc92ab0eadbc0e28d18645b945b4092')]

# %%
# Access just the 'body' argument from the tool call
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Hi John,
#
# No problem—thanks for letting me know. I’m available to reschedule. Are you available tomorrow at 10:00 AM or 2:00 PM? If neither time works, please share a couple of alternatives and I’ll adjust.
#
# Best regards,
# Seán

# %% [markdown]
# ## Approve

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}
    ), 
    config=config # Same thread ID to resume the paused conversation
)

pprint(response)

# %% [markdown]
# ## Reject

# %%
response = agent.invoke(
    Command(        
        resume={
            "decisions": [
                {
                    "type": "reject",
                    # An explanation of why the request was rejected
                    "message": "No please sign off - Your merciful leader, Seán."
                }
            ]
        }
    ), 
    config=config # Same thread ID to resume the paused conversation
    )   

pprint(response)

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])

# %% [markdown]
# ## Edit

# %%
response = agent.invoke(
    Command(        
        resume={
            "decisions": [
                {
                    "type": "edit",
                    # Edited action with tool name and args
                    "edited_action": {
                        # Tool name to call.
                        # Will usually be the same as the original action.
                        "name": "send_email",
                        # Arguments to pass to the tool.
                        "args": {"body": "This is the last straw, you're fired!"},
                    }
                }
            ]
        }
    ), 
    config=config # Same thread ID to resume the paused conversation
    )   

pprint(response)
# Out:
# {'email': "Hi Seán, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Please read my email and send a response immediately. Send the reply now in the same thread.', additional_kwargs={}, response_metadata={}, id='b7284f81-7bad-4e40-9375-6a10c3676487'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 339, 'prompt_tokens': 167, 'total_tokens': 506, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D91Eg9XQamcLpb7Pzl4PXYQHJp9oa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c5a55-6d64-7da1-87f5-02a054eba152-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'call_f0tHN7O8j4qOECidBloP0a29', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 167, 'output_tokens': 339, 'total_tokens': 506, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#               ToolMessage(content="Hi Seán, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='51e0ae52-53d4-4596-bb46-5039cec21bdb', tool_call_id='call_f0tHN7O8j4qOECidBloP0a29'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 916, 'prompt_tokens': 214, 'total_tokens': 1130, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D91EkA2oExRd5JXuzw1mFU755M0er', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c5a55-7d91-7132-a167-ad202295f4d3-0', tool_calls=[{'type': 'tool_call', 'name': 'send_email', 'args': {'body': "This is the last straw, you're fired!"}, 'id': 'call_1zxmyUzVIFVrLDZW8L46f4z0'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 916, 'total_tokens': 1130, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               ToolMessage(content='Email sent', name='send_email', id='8f7b7463-eac5-41bc-b6b7-2c92b1c5f0dc', tool_call_id='call_1zxmyUzVIFVrLDZW8L46f4z0'),
#               AIMessage(content='I made a mistake by sending an unprofessional reply. I can provide a professional response you can use in the same thread. Please confirm if you’d like me to send this now.\n\nSuggested professional reply:\nHi John, thanks for the update. No problem—these things happen. Could you propose a new time for tomorrow that works for you? If you’d like, I can suggest a couple of options: 11:00 AM or 3:00 PM. Please let me know what works, and I’ll adjust the schedule accordingly.\n\nWould you like me to send this in the same thread now? If you have preferred times or a different tone, tell me and I’ll tailor it.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1685, 'prompt_tokens': 252, 'total_tokens': 1937, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1536, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D91F1H0hEcjQcsMVIDsNhtXWNFjbK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c5a55-c132-7822-b256-158ba84cea00-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 252, 'output_tokens': 1685, 'total_tokens': 1937, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1536}})]}
