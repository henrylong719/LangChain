# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one—the Moon has no government or cities. It’s a natural satellite of Earth. (In fiction, authors sometimes invent names like “Lunagrad” or “Moon City,” but there’s no real capital.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 439, 'prompt_tokens': 13, 'total_tokens': 452, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7StLYNmQxkj7qhzKCiMCMrQaftkv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4442-5f95-7802-91c3-5e36906fbde5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 439, 'total_tokens': 452, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})

# %%
print(response.content)
# Out:
# There isn’t one—the Moon has no government or cities. It’s a natural satellite of Earth. (In fiction, authors sometimes invent names like “Lunagrad” or “Moon City,” but there’s no real capital.)

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-D7StLYNmQxkj7qhzKCiMCMrQaftkv',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 439,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 384,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 452}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or borders, so it has no capital city. If you’re writing fiction, you could invent a capital (e.g., “Lunagrad” or “Selene”)—but officially, none exists.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way that countries on Earth do. It's a celestial body without any human settlements or governments.
#
# So, the answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='3ee778b6-f331-440f-ad8d-0118c534bd75'),
#               AIMessage(content='- Literal answer: There is no capital—the Moon isn’t a country or government.\n- Riddle variant: The capital would be "M" (the capital letter of the word "Moon").', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 816, 'prompt_tokens': 13, 'total_tokens': 829, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7SwSc5GfzgPqE5lLXTbTJn4OV6Sk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4445-4bae-7411-a721-2d8115130dfd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 816, 'total_tokens': 829, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}

# %%
print(response['messages'][-1].content)
# Out:
# - Literal answer: There is no capital—the Moon isn’t a country or government.
# - Riddle variant: The capital would be "M" (the capital letter of the word "Moon").

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='b0d31965-9c0b-4ca4-82f4-28164ef97e00'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='2ef4e605-6c0e-4c98-9826-f9d7cbaf8d96', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='c7f7943c-6199-48e4-a548-6098bca40480'),
#               AIMessage(content='It sounds like you’re talking about a fictional concept, since there’s no real Luna City or capital on the Moon. If you’d like, here’s a detailed fictional take you can use for world-building or a story.\n\nPremise\n- Luna City is the Moon’s capital in a future where Earth and Moon governments operate a cooperative lunar colony. It’s a sprawling, subterranean metropolis built inside a network of basalt lava tubes, with surface domes for daylight and growing areas.\n\nLocation and design\n- Location: a clustered lava-tube system beneath the Moon’s near side, with surface entrances near the terminator to give crews a mix of solar energy and shade.\n- Architecture: layered districts connected by magnetically levitated trains and vertical transit shafts. A central luminous spine, the Lumen Spire, houses communications, data cores, and ceremonial spaces.\n- Environment: 1/6 g gravity, advanced life-support with closed-loop recycling, and radiation shielding created by thick regolith shields and underground habitats.\n\nGovernment and society\n- Government: Moon Authority, a semi-autonomous federal body with a Lunar Council representing districts, research stations, and mining settlements. An independent AI Ethics Council ensures transparency and safety.\n- Population: scientists, engineers, miners, healthcare workers, educators, and service industries. AIs and human-robot crews are integrated into everyday life.\n- Culture: a mix of scientific pragmatism and lunar artistry—illuminated art in tunnels, light-based performances, and holographic museums that travel between domes.\n\nEconomy and infrastructure\n- Core industries: helium-3 and rare-earth mining (in safety-checked regions), water ice extraction from shadowed craters, biotech and life-support technology, and lunar tourism for surface day-trips.\n- Energy: solar farms on the surface, supplemented by compact nuclear microreactors for continuous power during long lunar nights.\n- Infrastructure: surface domes for agriculture (algae and hydroponics), water recovery facilities, and a robust telepresence network for Earth-to-Muna communications.\n\nKey districts and landmarks (fictional ideas)\n- The Lumen Spire: ceremonial and administrative heart, with an astronomical observatory at the top.\n- Crater Gate District: a historic entrance hub and market plaza where traders mingle with researchers.\n- Mare Forum: a public square carved into a lava-tube, hosting debates, art performances, and press briefings.\n- The Observatory Arcades: science lounges and small labs; a popular place for citizen-scientists.\n- Echo Dome: a cultural venue with acoustics that bend sound through the hollow tubes, used for concerts and broadcasts.\n- Ice Hall: a public space for ice-work sculptures and exhibitions, sourced from polar regolith deposits.\n\nDaily life and challenges\n- Life: residents live in modular habitat pods clustered around transit hubs. Meals come from local farms and hydroponics; water and air are recycled in closed loops.\n- Transportation: maglev shuttles between districts, aerial drones for cargo, and personal mobility boosters in some areas.\n- Challenges: radiation storms and micrometeoroid strikes are mitigated by shielded corridors; dust management in surface approaches; resource logistics between polar ice mines and underground processing.\n- Tensions: debates over resource allocation, corporate influence vs. public good, and exploration ethics regarding untouched lunar sites.\n\nStory hooks and vibe\n- A non-linear political crisis tests the Lunar Council as a life-support failure isolates a district.\n- An investigator uncovers a hidden chamber beneath the Lumen Spire with data that could change Moon-Earth relations.\n- A corporate hit squad targets a citizen-science project that threatens a lucrative supply line.\n- A quiet romance blooms between an engineer and an AI technician navigating cultural divides.\n\nIf you want, I can:\n- tai ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Reality check: there is no real capital of the Moon. The Moon has no government. If you’re looking for a fully imagined, detailed setting, here’s a complete concept for Luna City as the Moon’s capital. It’s designed to feel plausible, grounded in current science-ish tech, and rich enough for stories, games, or worldbuilding.
#
# Luna City: an overview
# - Role: The political, cultural, and economic capital of a unified lunar polity. It houses the main legislature, the executive offices, major courts, the central stock exchange for lunar credits, and the largest research and cultural complexes.
# - Location: On the near side, near the equator, built into a large crater with a ring of shielded domes along the rim. This gives easy line-of-sight communication with Earth and abundant solar exposure during the “day” part of the 28–29 Earth day cycle. The crater’s floor hosts subterranean layers for life support and industry.
# - Population: About 1.2 to 1.5 million residents at peak capacity, with a steady inflow of scientists, engineers, administrators, and service workers. A sizable portion are “Lunars” — people born on the Moon or raised in lunar habitats — who form a distinct culture alongside Earth-born settlers.
# - Tone and vibe: A high-tech, risk-aware, bureaucratically dense metropolis that nevertheless feels intimate due to the close quarters of domed neighborhoods and the shared experience of living in low gravity and under vacuum-safe roofs.
#
# Founding and history (brief arc)
# - Founding era: Late 21st to early 22nd century. After a century of mining and research outposts, a Coalition for Lunar Governance forms a unified lunar state with Luna City as its ceremonial and administrative capital.
# - Key milestones:
#   - The Ring of Glass: the first ring of large, pressure-sealed domes around the crater, housing government offices and a public square beneath transparent arcologies.
#   - The Ice Gate and Water Ring: a network that taps permanently shadowed craters for water ice, enabling life support, agriculture, and industry.
#   - The Solstice Accord: a treaty with Earth nations formalizing governance, resource rights, and Earth-Lunar cooperation while preserving lunar autonomy in domestic affairs.
#   - The Grand Senate District opens, consolidating law, education, and culture under one jurisdiction, making Luna City the political heart of the Moon.
#
# Government, politics, and law
# - System: A representative parliamentary system within a Lunar Autonomous Republic (LAR). A President-Director serves as head of state, while a Prime Minister or Chief Executive runs day-to-day governance. A bicameral Lunar Assembly (Council of Craters) handles legislation; a lunar Supreme Court oversees constitutional matters.
# - Key institutions:
#   - The Constellation Senate: upper house, representing districts by population and by historic lunar features (ice, dust, regolith, science, industry).
#   - The Lunar Directorate: executive cabinet responsible for security, resource management, and interplanetary diplomacy.
#   - The Lunar Court of Echoes: a judiciary that blends civil law with technocratic regulatory codes for mining, air quality, and habitat safety.
#   - The Commission on Luna Tech and Resource Allocation: oversees AI-guided planning, mining rights, and water/ice purification.
# - Earth-Luna relations: Earth maintains a council with seats in Luna City but cannot override lunar law; Earth still funds major infrastructure and telecom satellites. The balance is delicate: Earth provides capital and markets, lunar institutions provide autonomy and rapid policymaking for local needs.
#
# Geography and districts
# - Core districts:
#   - The Grand Dome District: home to the Assembly, ministries, central plaza, and major legal institutions.
#   - The Blue Ring: education, universities, think-tanks, and cultural centers; hosts the annual Lunar Knowledge Festival.
#   - The Ice Gate Zone: water ice processing, cryo-storage facilities, and hydroponic farms; protective enclosures shield workers from diurnal temperature swings.
#   - The Helix District: high-tech manufacturing, AI-affinity labs, and robotics centers; cutting-edge 3D printing and materials research.
#   - The Skyways Quarter: residential neighborhoods, medical clinics, and day-care facilities; interconnected by magnetic-levitation transit tubes.
# - Subsurface network: A labyrinth of lava-tube tunnels repurposed as data centers, long-term archives, and climate-controlled living spaces. This reduces surface radiation exposure and stabilizes temperatures.
# - Key landmarks:
#   - The Glass Spire: a communications hub with a giant solar array and a beacon visible across the lunar farside in emergencies.
#   - The Lunari Opera House: a world-class venue for performances, with acoustics optimized for near-vacuum amplification.
#   - The Observatory Ring: a ring of telescopes and spectrometers that monitor Earth-Moon space traffic, solar activity, and deep-space signals.
#   - The Archive of Echoes: a vast, climate-controlled library containing lunar geology, ice core data, and the history of lunar exploration.
#
# Architecture, engineering, and daily life
# - Architecture: A blend of practicality and beauty. Pressure-sealed domes use transparent membranes and smart glass. Internal climate control mimics Earth-like seasons, despite a 14–29 day day-night cycle. Structures emphasize radiation shielding by soil, regolith, and water-rich layers.
# - Materials and tech:
#   - 3D-printed regolith alloys and ultralight composites.
#   - Local power: a mix of solar arrays, small modular nuclear reactors, and advanced energy storage in the form of cryogenic or solid-state buffers.
#   - Life support: closed-loop systems for air and water; agricultural cycles with hydroponics and agro-bioreactors.
#   - Mobility: maglev corridors, autonomous rover shuttles, and airless tube transit to minimize energy use in vacuum.
# - Everyday life:
#   - Housing: modular apartments with playfully sculpted interiors to counter the feeling of confinement in low gravity.
#   - Food: a strong emphasis on hydroponics and lab-grown proteins; social meals feature lunar-grown greens and Earth imports in seasonal cycles.
#   - Work-life rhythm: a 24/7 city adjusted to the Moon’s natural light cycle, with “solar peak” and “shadow trough” shifts for energy use and health rhythms.
#   - Recreation: low-gravity sports arenas, zero-G labs for microgravity experiments, and cultural festivals that celebrate lunar seasons and Earth lunar anniversaries.
#
# Economy and industry
# - Main assets:
#   - Water ice extraction and processing (crucial for life support, agriculture, and rocket fuel).
#   - Helium-3 and rare earth elements for energy storage, electronics, and research equipment.
#   - Manufacturing in space and on the Moon, including 3D-printed components for spacecraft, habitats, and consumer goods.
# - Currency and trade:
#   - Lunar Credits (LC) used in Luna City; exchange with Earth currencies at official Lunar Exchange Banks.
#   - International partnerships for research, tourism, and resource sharing.
# - Labor and education: A large portion of the population is trained in STEM fields, with substantial investment in vocational schools for mining, robotics maintenance, and habitat engineering.
#
# Society, culture, and daily life
# - Demographics: A diverse mix of Earth expatriates, lunar-born residents, scientists, miners, and service workers. Mixed languages (Earth-based languages plus lunar patois and sign language) with English and Mandarin as common lingua francas; lunar slang reflects gravity differences (e.g., “down-to-earth” is both literal and metaphorical).
# - Culture and identity:
#   - Lunars: a culture shaped by living in 1/6 g and in compact, shielded spaces. They emphasize communal resilience, craftsmanship, and a shared sense of frontier heritage.
#   - Public life: regular public gatherings at domed plazas, outdoor markets inside shielded atriums, and evening concerts in the Grand Dome.
#   - Holidays: Solstice Day (marking the start/end of the lunar night shifts), Ice Night (celebrate ice harvest and resilience), and the Founders’ Night (commemorating the founding of Luna City).
# - Education and science culture: Strong focus on STEM, planetary science, and arts; science fairs, lunar archaeology clubs, and citizen science projects are common.
#
# Security, defense, and safety
# - Threats considered:
#   - Solar storms and radiation bursts require robust shielding and emergency shelters.
#   - Micro-meteoroid impacts and surface hazards demand rapid dust filtration and armor for public spaces.
#   - Political tensions with Earth factions and other space-faring entities over resources.
# - Security framework:
#   - Lunar Security Service (LSS): civilian police, emergency responders, and cyber-nonproliferation units.
#   - Habitat security: sealed entrances, airlocks, and radiation monitoring for every district.
#   - Disaster response: fire suppression adapted to vacuum and pressurized environments; rapid evacuation tubes to central shelters.
# - Civil liberties: Emphasis on privacy in a highly networked city; trade-offs with surveillance needed for life-support integrity and resource allocation.
#
# Notable places and landmarks
# - The Grand Dome: central government complex with transparent ceilings, allowing daylight into offices and public halls.
# - The Archive of Echoes: immense repository of lunar geology samples, mission logs, and treaty documents.
# - The Ice Gate: primary water-ice processing plant and cold storage; guarded but accessible to researchers.
# - The Crypteon Library: a public museum and research center for lunar history, including early outposts and the evolution of lunar governance.
# - The Helix Research District: innovation hub for robotics, AI, and spacecraft components.
# - The Lunari Opera House and Sky Theater: cultural hubs for music, theater, and cinema in a gravity-tuned hall.
#
# Key figures (sample archetypes)
# - The Director-General: a pragmatic, consensus-builder who balances Earth interests with lunar autonomy.
# - The Chief Architect: a visionary designer who integrates art with engineering, shaping the city’s domes and tubes.
# - The Lunar Archivist: custodian of the Archive of Echoes, preserving lunar history and guiding citizen researchers.
# - The Captain of the Ice Gate: leads safety and resource operations at the water-ice facility.
# - A rising political figure in the Lunar Assembly who advocates for increased lunar self-sufficiency.
#
# Potential story hooks and worldbuilding prompts
# - A water-ice shipment goes missing from the Ice Gate, triggering a Moon-wide investigation that reveals a web of political interference and corporate espionage.
# - A new solar storm knocks Luna City offline; citizens must survive in a partial blackout as life-support systems rely on stored energy and emergency protocols.
# - A controversial treaty with Earth threatens lunar autonomy; a young legislator uncovers a back-channel agreement that could reshape the Moon’s future.
# - An archeological discovery in a subsurface tunnel hints at an ancient, pre-human presence on the Moon, challenging lunar identity and law.
# - A festival in the Grand Dome reveals a hidden talent in a nonhuman AI or synthetic life form living in the city’s data nets.
#
# If you’d like, I can tailor Luna City to a specific tone (gritty cyberpunk, utopian sci-fi, noir-diplomatic, etc.), pick a different location on the Moon (far side, polar regions, or a lava-tube megacity), or shift political relationships (Earth-led colony vs. fully independent lunar state). Tell me your preferred era, mood, and purpose (game, novel, screenplay, or worldbuilding exercise), and I’ll adjust the details accordingly.
