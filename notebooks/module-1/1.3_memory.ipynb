# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='5fd56104-546d-4880-8ab0-39db058b8c22'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great color—calm and vibrant. What would you like to chat about today? I can suggest topics like nature, design, technology, or anything you’re into.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 631, 'prompt_tokens': 18, 'total_tokens': 649, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7U8JwhydpEoYBzTqns2HepQe1mGC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c448b-32ee-74a2-bc38-b813d4e2dcaa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 631, 'total_tokens': 649, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='f168e31b-f631-4a7c-822d-66d598b926f8'),
#               AIMessage(content='I don’t know your favourite color yet—what is it? If you want, I can help you figure it out with a quick, 3-question mini-quiz:\n\n1) Do you prefer cool tones (blue/green/purple) or warm tones (red/orange/yellow)?\n2) Do you like bright, saturated colors or softer, pastel shades?\n3) Is the color for clothing, a room/space, or something else?\n\nAnswer and I’ll suggest a color that fits. Or if you want a random guess, blue is a very common favorite.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1405, 'prompt_tokens': 11, 'total_tokens': 1416, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1280, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7U8ZKEThB3zdXadQMxyPau2t33lD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c448b-6ff9-70d0-8f83-cdc22322b60a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 1405, 'total_tokens': 1416, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1280}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='04698cf6-6a14-459f-a393-cc0e2026eb53'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—calming and nature-inspired. If you’d like, I can remember that as your favorite color for this chat. What would you like to do today? We could chat about colors, Irish culture or language, or I can help with something specific you have in mind.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 653, 'prompt_tokens': 18, 'total_tokens': 671, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7U9wDWLX12eFdhHtNLMn5AVUQ8jB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c448c-bd42-7d01-bca0-437b33ea00c8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 653, 'total_tokens': 671, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='04698cf6-6a14-459f-a393-cc0e2026eb53'),
#               AIMessage(content='Nice to meet you, Seán! Green is a great color—calming and nature-inspired. If you’d like, I can remember that as your favorite color for this chat. What would you like to do today? We could chat about colors, Irish culture or language, or I can help with something specific you have in mind.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 653, 'prompt_tokens': 18, 'total_tokens': 671, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7U9wDWLX12eFdhHtNLMn5AVUQ8jB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c448c-bd42-7d01-bca0-437b33ea00c8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 653, 'total_tokens': 671, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='035c982f-c96b-4354-8b3d-d1ea67e89c0c'),
#               AIMessage(content='Your favourite colour is green. Want me to remember that for this chat? What would you like to do next—chat about colors, Irish culture or language, or something else?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 557, 'prompt_tokens': 101, 'total_tokens': 658, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7UAT8FuCxO1nr6jEgcLSznZhWo85', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c448d-3ada-7ce0-878b-50f91c0a8735-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 101, 'output_tokens': 557, 'total_tokens': 658, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}
